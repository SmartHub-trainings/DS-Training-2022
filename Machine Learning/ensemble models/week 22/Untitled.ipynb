# %%
import joblib

# %%
model=joblib.load("selected_model.pk1")

# %%
model
# Out:
# KNeighborsClassifier(n_neighbors=31)

# %%
model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 31,
#  'p': 2,
#  'weights': 'uniform'}
