# %%
import pandas as pd

# %%
df=pd.read_csv("../../../datasets/supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
columns=df.columns

# %%
new_cols=[]
for column in columns:
    new_cols.append("_".join(column.split(" ")))

# %%
df.columns=new_cols

# %%
df.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice_ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer_type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product_line             1000 non-null   object
#  6   Unit_price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax_5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit_price     Quantity       Tax_5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross_margin_percentage  gross_income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
for column in new_cols:
    print(column)
    print(len(df[column].unique()))
    print()
# Out:
# Invoice_ID
# 1000
#
# Branch
# 3
#
# City
# 3
#
# Customer_type
# 2
#
# Gender
# 2
#
# Product_line
# 6
#
# Unit_price
# 943
#
# Quantity
# 10
#
# Tax_5%
# 990
#
# Total
# 990
#
# Date
# 89
#
# Time
# 506
#
# Payment
# 3
#
# cogs
# 990
#
# gross_margin_percentage
# 1
#
# gross_income
# 990
#
# Rating
# 61

# %%
df.select_dtypes("object")
# Out:
#       Invoice_ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line       Date   Time      Payment
# 0         Health and beauty   1/5/2019  13:08      Ewallet
# 1    Electronic accessories   3/8/2019  10:29         Cash
# 2        Home and lifestyle   3/3/2019  13:23  Credit card
# ...

# %%
columns=[]
for column in df.select_dtypes("object"):
    if(column in ["Invoice_ID","Date","Time"]):
        continue
    columns.append(column)
    print(column)
    print(df[column].unique())
    print(len(df[column].unique()))
    
    print()
print(columns)
# Out:
# Branch
# ['A' 'C' 'B']
# 3
#
# City
# ['Yangon' 'Naypyitaw' 'Mandalay']
# 3
#
# Customer_type
# ['Member' 'Normal']
# 2
#
# Gender
# ['Female' 'Male']
# 2
#
# Product_line
# ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
# 6
#
# Payment
# ['Ewallet' 'Cash' 'Credit card']
# 3
#
# ['Branch', 'City', 'Customer_type', 'Gender', 'Product_line', 'Payment']

# %%
df.memory_usage(deep=True).sum()
# Out:
# 647207

# %%
df1=pd.get_dummies(df,columns=columns,drop_first=True)

# %%
df1.head()
# Out:
#     Invoice_ID  Unit_price  Quantity   Tax_5%     Total       Date   Time  \
# 0  750-67-8428       74.69         7  26.1415  548.9715   1/5/2019  13:08
# 1  226-31-3081       15.28         5   3.8200   80.2200   3/8/2019  10:29
# 2  631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 3  123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 4  373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#      cogs  gross_margin_percentage  gross_income  ...  City_Yangon  \
# 0  522.83                 4.761905       26.1415  ...            1
# 1   76.40                 4.761905        3.8200  ...            0
# 2  324.31                 4.761905       16.2155  ...            1
# 3  465.76                 4.761905       23.2880  ...            1
# 4  604.17                 4.761905       30.2085  ...            1
#
#    Customer_type_Normal  Gender_Male  Product_line_Fashion accessories  \
# ...

# %%
df1.drop(["Invoice_ID","Date","Time"],inplace=True,axis=1)

# %%
df1.head()
# Out:
#    Unit_price  Quantity   Tax_5%     Total    cogs  gross_margin_percentage  \
# 0       74.69         7  26.1415  548.9715  522.83                 4.761905
# 1       15.28         5   3.8200   80.2200   76.40                 4.761905
# 2       46.33         7  16.2155  340.5255  324.31                 4.761905
# 3       58.22         8  23.2880  489.0480  465.76                 4.761905
# 4       86.31         7  30.2085  634.3785  604.17                 4.761905
#
#    gross_income  Rating  Branch_B  Branch_C  ...  City_Yangon  \
# 0       26.1415     9.1         0         0  ...            1
# 1        3.8200     9.6         0         1  ...            0
# 2       16.2155     7.4         0         0  ...            1
# 3       23.2880     8.4         0         0  ...            1
# 4       30.2085     5.3         0         0  ...            1
#
#    Customer_type_Normal  Gender_Male  Product_line_Fashion accessories  \
# ...

# %%
X,y=df1.drop("Rating",axis=1),df1.Rating

# %%
X.shape
# Out:
# (1000, 20)

# %%
y.shape
# Out:
# (1000,)

# %%
corr=df1.corr()

# %%
corr
# Out:
#                                   Unit_price  Quantity    Tax_5%     Total  \
# Unit_price                          1.000000  0.010778  0.633962  0.633962
# Quantity                            0.010778  1.000000  0.705510  0.705510
# Tax_5%                              0.633962  0.705510  1.000000  1.000000
# Total                               0.633962  0.705510  1.000000  1.000000
# cogs                                0.633962  0.705510  1.000000  1.000000
# gross_margin_percentage                  NaN       NaN       NaN       NaN
# gross_income                        0.633962  0.705510  1.000000  1.000000
# Rating                             -0.008778 -0.015815 -0.036442 -0.036442
# Branch_B                           -0.000342 -0.006773 -0.008876 -0.008876
# Branch_C                            0.024717  0.017291  0.040176  0.040176
# City_Naypyitaw                      0.024717  0.017291  0.040176  0.040176
# ...

# %%
df1.head()
# Out:
#    Unit_price  Quantity   Tax_5%     Total    cogs  gross_margin_percentage  \
# 0       74.69         7  26.1415  548.9715  522.83                 4.761905
# 1       15.28         5   3.8200   80.2200   76.40                 4.761905
# 2       46.33         7  16.2155  340.5255  324.31                 4.761905
# 3       58.22         8  23.2880  489.0480  465.76                 4.761905
# 4       86.31         7  30.2085  634.3785  604.17                 4.761905
#
#    gross_income  Rating  Branch_B  Branch_C  ...  City_Yangon  \
# 0       26.1415     9.1         0         0  ...            1
# 1        3.8200     9.6         0         1  ...            0
# 2       16.2155     7.4         0         0  ...            1
# 3       23.2880     8.4         0         0  ...            1
# 4       30.2085     5.3         0         0  ...            1
#
#    Customer_type_Normal  Gender_Male  Product_line_Fashion accessories  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(corr)
plt.colorbar()

# %%
import seaborn as sns

# %%
sns.heatmap(corr,vmin=-1.0,vmax=1.0)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)

# %%
## Model
