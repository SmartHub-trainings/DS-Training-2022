# %%
23+5
# Out:
# 28

# %%
4*4
# Out:
# 16

# %%
input()
# Out:
# 45
# '45'

# %%
a=23
b=45
c=a+b
print(c)
# Out:
# 68

# %%
a+30
# Out:
# 53

# %% [markdown]
# # Data types

# %% [markdown]
# * Simple data types
#     * integer
#     * floats
#     * strings
#     * complex
#     * boolean
# * Containers
#     * List
#     * tuple
#     * sets
#     * dictionary
# * user defined (classes and objects)

# %% [markdown]
# ## complex data type

# %%
4+5j
# Out:
# (4+5j)

# %%
w=4-3j

# %%
w
# Out:
# (4-3j)

# %%
z=5+5j

# %%
w+z
# Out:
# (9+2j)

# %%
z*w
# Out:
# (35+5j)

# %%
z/w
# Out:
# (0.2+1.4j)

# %%
z
# Out:
# (5+5j)

# %%
w
# Out:
# (4-3j)

# %%
w.imag
# Out:
# -3.0

# %%
w.real
# Out:
# 4.0

# %%
w.conjugate()
# Out:
# (4+3j)
