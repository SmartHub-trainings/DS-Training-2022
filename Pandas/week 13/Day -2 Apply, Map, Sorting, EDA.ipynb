# %%
import pandas as pd

# %%
df=pd.read_csv("../../datasets/titanic/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.drop(["PassengerId"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/3478790274.py in <module>
# ----> 1 df.drop(["PassengerId"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df1=df.drop(["PassengerId"],axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.drop(["PassengerId"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df=pd.read_csv("../../datasets/titanic/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2=df.set_index("PassengerId")

# %%
df2.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
drinks=pd.read_csv("../../datasets/drinks.csv")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.set_index("country")
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
drinks.set_index("continent")
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
# ...                ...            ...              ...            ...
# SA           Venezuela            333              100              3
# AS             Vietnam            111                2              1
# AS               Yemen              6                0              0
# AF              Zambia             32               19              4
# AF            Zimbabwe             64               18              4
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# ...

# %%
drinks.continent.unique().shape
# Out:
# (6,)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/427277643.py in <module>
# ----> 1 drinks.loc["AS"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
drinks_mod=drinks.set_index("continent")

# %%
drinks_mod.loc["AS",:]
# Out:
#                         country  beer_servings  spirit_servings  \
# continent
# AS                  Afghanistan              0                0
# AS                      Bahrain             42               63
# AS                   Bangladesh              0                0
# AS                       Bhutan             23                0
# AS                       Brunei             31                2
# AS                     Cambodia             57               65
# AS                        China             79              192
# AS                  North Korea              0                0
# AS                        India              9              114
# AS                    Indonesia              5                1
# AS                         Iran              0                0
# AS                         Iraq              9                3
# AS                       Israel             63               69
# ...

# %%
drinks_mod.sort_index()
# Out:
#                                 country  beer_servings  spirit_servings  \
# continent
# AF                             Zimbabwe             64               18
# AF                           Seychelles            157               25
# AF                              Senegal              9                1
# AF                              Lesotho             82               29
# AF                               Rwanda             43                2
# ...                                 ...            ...              ...
# NaN                   St. Kitts & Nevis            194              205
# NaN                           St. Lucia            171              315
# NaN        St. Vincent & the Grenadines            120              221
# NaN                   Trinidad & Tobago            197              156
# NaN                                 USA            249              158
#
#            wine_servings  total_litres_of_pure_alcohol
# continent
# ...

# %%
drinks.isna().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.set_index(["continent","country"])
# Out:
#                        beer_servings  spirit_servings  wine_servings  \
# continent country
# AS        Afghanistan              0                0              0
# EU        Albania                 89              132             54
# AF        Algeria                 25                0             14
# EU        Andorra                245              138            312
# AF        Angola                 217               57             45
# ...                              ...              ...            ...
# SA        Venezuela              333              100              3
# AS        Vietnam                111                2              1
#           Yemen                    6                0              0
# AF        Zambia                  32               19              4
#           Zimbabwe                64               18              4
#
#                        total_litres_of_pure_alcohol
# continent country
# ...

# %%
drinks.set_index(["continent","country"]).sort_index()
# Out:
#                                         beer_servings  spirit_servings  \
# continent country
# AF        Algeria                                  25                0
#           Angola                                  217               57
#           Benin                                    34                4
#           Botswana                                173               35
#           Burkina Faso                             25                7
# ...                                               ...              ...
# NaN       St. Kitts & Nevis                       194              205
#           St. Lucia                               171              315
#           St. Vincent & the Grenadines            120              221
#           Trinidad & Tobago                       197              156
#           USA                                     249              158
#
#                                         wine_servings  \
# continent country
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks_mod.head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# EU                                  4.9
# AF                                  0.7
# EU                                 12.4
# AF                                  5.9

# %%
drinks_mod.loc["AS","country"].iloc[0]
# Out:
# 'Afghanistan'

# %%
drinks_mod.loc["AS","country"].iloc[0]="uniport"
# Out:
# /Users/georgebsmith/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
drinks_mod.head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# EU                                  4.9
# AF                                  0.7
# EU                                 12.4
# AF                                  5.9

# %%
drinks_mod.loc["AS","country"].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/2055520512.py in <module>
# ----> 1 drinks_mod.loc["AS","country"].iloc[0]._setitem_single_block()
#
# AttributeError: 'str' object has no attribute '_setitem_single_block'

# %%
drinks_mod.loc["AS","country"].str.replace("Afghanistan","uniport")
# Out:
# continent
# AS                 uniport
# AS                 Bahrain
# AS              Bangladesh
# AS                  Bhutan
# AS                  Brunei
# AS                Cambodia
# AS                   China
# AS             North Korea
# AS                   India
# AS               Indonesia
# AS                    Iran
# AS                    Iraq
# AS                  Israel
# AS                   Japan
# AS                  Jordan
# AS              Kazakhstan
# AS                  Kuwait
# AS              Kyrgyzstan
# AS                    Laos
# AS                 Lebanon
# AS                Malaysia
# AS                Maldives
# AS                Mongolia
# AS                 Myanmar
# AS                   Nepal
# AS                    Oman
# AS                Pakistan
# AS             Philippines
# AS                   Qatar
# AS             South Korea
# AS      Russian Federation
# AS            Saudi Arabia
# AS               Singapore
# AS               Sri Lanka
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.nlargest(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/1289105713.py in <module>
# ----> 1 drinks.nlargest(5)
#
# TypeError: nlargest() missing 1 required positional argument: 'columns'

# %%
drinks.nlargest(5,"beer_servings")
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# 62                            8.9        AF
# 65                           11.3        EU
# 98                           12.9        EU

# %%
drinks.nlargest(1,"beer_servings")
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF

# %%
drinks.nsmallest(10,"beer_servings")
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 13                            0.0        AS
# 40                            5.9        OC
# ...

# %%
drinks.corr()
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
(drinks[["beer_servings","spirit_servings"]]
 .plot(x="beer_servings",y="spirit_servings",kind="scatter"))
# Out:
# <AxesSubplot:xlabel='beer_servings', ylabel='spirit_servings'>

# %% [markdown]
# ## Back titanic

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.Age>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
(df.Age>18).value_counts()
# Out:
# True     575
# False    316
# Name: Age, dtype: int64

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
~(df.Age.isna())
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
boolean_not_nan=~(df.Age.isna())

# %%
(df.Age[boolean_not_nan]>18).value_counts()
# Out:
# True     575
# False    139
# Name: Age, dtype: int64

# %%
z=(df.Age[boolean_not_nan]>18).value_counts()

# %%
z
# Out:
# True     575
# False    139
# Name: Age, dtype: int64

# %%
z.index=["Adults","Teenagers"]

# %%
z
# Out:
# Adults       575
# Teenagers    139
# Name: Age, dtype: int64

# %%
z.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Number of passengers with siblings onboard

# %%
df.SibSp.isna().sum()
# Out:
# 0

# %%
df.SibSp!=0
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: SibSp, Length: 891, dtype: bool

# %%
(df.SibSp!=0).sum()
# Out:
# 283

# %%
df.Cabin.isna().sum()
# Out:
# 687

# %%
df.plot(kind="bar",subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'PassengerId'}>,
#        <AxesSubplot:title={'center':'Survived'}>,
#        <AxesSubplot:title={'center':'Pclass'}>,
#        <AxesSubplot:title={'center':'Age'}>,
#        <AxesSubplot:title={'center':'SibSp'}>,
#        <AxesSubplot:title={'center':'Parch'}>,
#        <AxesSubplot:title={'center':'Fare'}>], dtype=object)

# %%
# df.value_counts().plot(kind="bar",subplots=True)

# %%
total_fare=df.Fare.sum()

# %%
(df.Fare/total_fare*100).round(2)
# Out:
# 0      0.03
# 1      0.25
# 2      0.03
# 3      0.19
# 4      0.03
#        ...
# 886    0.05
# 887    0.10
# 888    0.08
# 889    0.10
# 890    0.03
# Name: Fare, Length: 891, dtype: float64

# %%
df["PercFare"]=(df.Fare/total_fare*100).round(2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  PercFare
# 0      0         A/5 21171   7.2500   NaN        S      0.03
# 1      0          PC 17599  71.2833   C85        C      0.25
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.03
# 3      0            113803  53.1000  C123        S      0.19
# ...

# %%
df.Name.split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/3013306534.py in <module>
# ----> 1 df.Name.split(",")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
# df.Name.str.split(",")[0]

# %% [markdown]
# ## Map, apply and applymap methgods

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  PercFare
# 0      0         A/5 21171   7.2500   NaN        S      0.03
# 1      0          PC 17599  71.2833   C85        C      0.25
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.03
# 3      0            113803  53.1000  C123        S      0.19
# ...

# %%
df.Sex.map({"male":1,"female":0})
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
df["Sex_coded"]=df.Sex.map({"male":1,"female":0})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  PercFare  Sex_coded
# 0      0         A/5 21171   7.2500   NaN        S      0.03          1
# 1      0          PC 17599  71.2833   C85        C      0.25          0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.03          0
# ...

# %%
df.Age.apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15407/2141228710.py in <module>
# ----> 1 df.Age.apply(int)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
df.PercFare.apply(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: PercFare, Length: 891, dtype: int64

# %%
df.Fare.apply(int)
# Out:
# 0       7
# 1      71
# 2       7
# 3      53
# 4       8
#        ..
# 886    13
# 887    30
# 888    23
# 889    30
# 890     7
# Name: Fare, Length: 891, dtype: int64

# %%
def getName(name):
    return name.split(",")[0]

# %%
df["LastName"]=df.Name.apply(getName)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  PercFare  Sex_coded  \
# 0      0         A/5 21171   7.2500   NaN        S      0.03          1
# 1      0          PC 17599  71.2833   C85        C      0.25          0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.03          0
# ...
