# %%
def add(a,b):
    return a+b

# %%
add(4,6)
# Out:
# 10

# %%
x=float(input("Enter a number: "))
y=float(input("Enter a number: "))
add(x,y)
# Out:
# Enter a number: 23
# Enter a number: 78.5
# 101.5

# %%
add(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4c015eca70a5> in <module>
# ----> 1 add(3)
#
# TypeError: add() missing 1 required positional argument: 'b'

# %% [markdown]
# # Default argument

# %%
def add1(a,b=0):
    return a+b

# %%
add1(3,4)
# Out:
# 7

# %%
add1(4)
# Out:
# 4

# %%
def comment(name,content):
    return f"{name}=>{content}"

# %%
comment("Smith","This is bad!!")
# Out:
# 'Smith=>This is bad!!'

# %%
comment("George")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e7f8f28998a7> in <module>
# ----> 1 comment("George")
#
# TypeError: comment() missing 1 required positional argument: 'content'

# %%
def comment(name,content="??"):
    return f"{name}=>{content}"

# %%
comment("Dan")
# Out:
# 'Dan=>??'

# %%
def comment(name="Anonnymous",content):
    return f"{name}=>{content}"
# Out:
#   File "<ipython-input-14-2a1f49667660>", line 1
#     def comment(name="Anonnymous",content):
#                ^
# SyntaxError: non-default argument follows default argument

# %%
def comment(content,name="Anonnymous"):
    return f"{name}=>{content}"

# %%
comment("He is mad")
# Out:
# 'Anonnymous=>He is mad'

# %%
def prod(a=1,b=1):
    return a*b

# %%
prod()
# Out:
# 1

# %%
def diff(a=0,b=0):
    return a-b

# %%
diff()
# Out:
# 0

# %%
diff(3)
# Out:
# 3

# %%
diff(2,5)
# Out:
# -3

# %%
diff(b=2,a=10)
# Out:
# 8

# %%
diff(4,5)
# Out:
# -1

# %%
diff(a=5,b=4)
# Out:
# 1

# %% [markdown]
# ## Exception Handling

# %%
a=float(input("Enter a number: "))
b=float(input("Enter a number: "))
print(a/b)
# Out:
# Enter a number: 23
# Enter a number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-30-c3709a0dabea> in <module>
#       1 a=float(input("Enter a number: "))
#       2 b=float(input("Enter a number: "))
# ----> 3 print(a/b)
#
# ZeroDivisionError: float division by zero

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except:
    print("Something went wrong!")
# Out:
# Enter a number: 12
# Enter a number: 0
# Something went wrong!

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except:
    print("You cant divide by zero")
# Out:
# Enter a number: 12
# Enter a number: 0
# You cant divide by zero

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except:
    print("You cant divide by zero")
# Out:
# Enter a number: 12
# Enter a number: 89y
# You cant divide by zero

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except ZeroDivisionError:
    print("You cant divide by zero")
# Out:
# Enter a number: 12
# Enter a number: 09u
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-23adba1b2312> in <module>
#       1 try:
#       2     a=float(input("Enter a number: "))
# ----> 3     b=float(input("Enter a number: "))
#       4     print(a/b)
#       5 except ZeroDivisionError:
#
# ValueError: could not convert string to float: '09u'

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except ZeroDivisionError:
    print("You cant divide by zero")
except ValueError:
    print("Only numbers are allowed")
# Out:
# Enter a number: 12
# Enter a number: ui7
# Only numbers are allowed

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    print(a/b)
except ZeroDivisionError:
    print("You cant divide by zero")
except ValueError:
    print("Only numbers are allowed")
except:
    print("Ooooop!!!")
# Out:
# Enter a number: we
# Only numbers are allowed

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    d=a/b
    print(d)
except ZeroDivisionError:
    print("You cant divide by zero")
except ValueError:
    print("Only numbers are allowed")
except:
    print("Ooooop!!!")

# %%
try:
    a=float(input("Enter a number: "))
    b=float(input("Enter a number: "))
    d=a/b
    
except ZeroDivisionError:
    print("You cant divide by zero")
except ValueError:
    print("Only numbers are allowed")
except:
    print("Ooooop!!!")
else:
    print(d)
finally:
    print("Done")
# Out:
# Enter a number: 12
# Enter a number: 0
# You cant divide by zero
# Done

# %%
from random import randint
def fairDice():
    die1=randint(1,6)
    die2=randint(1,6)
    return die1+die2

# %%
fairDice()
# Out:
# 6

# %%
occurence={}
for i in range(2,13):
        occurence[i]=0
for i in range(1000):
    outcome=fairDice()
    occurence[outcome]+=1
print(occurence)
 
    
# print(occurence)
#     print(fairDice())
# Out:
# {2: 27, 3: 71, 4: 91, 5: 107, 6: 140, 7: 158, 8: 139, 9: 124, 10: 69, 11: 47, 12: 27}

# %%
occurence={i:0 for i in range(2,13)} # dictionary comprehesion
for i in range(1000):
    outcome=fairDice()
    occurence[outcome]+=1
print(occurence)
# Out:
# {2: 23, 3: 58, 4: 81, 5: 117, 6: 148, 7: 177, 8: 115, 9: 121, 10: 79, 11: 53, 12: 28}

# %%
x={a:a*2 for a in range(5)}

# %%
x
# Out:
# {0: 0, 1: 2, 2: 4, 3: 6, 4: 8}
