# %% [markdown]
# # Dictionary

# %%
person={"name":"Smith","age":52,
        "marital status":"married",
       "likes":["Singing","Dancing"]}

# %%
type(person)
# Out:
# dict

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 52,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing']}

# %%
person["name"]
# Out:
# 'Smith'

# %%
person["likes"]
# Out:
# ['Singing', 'Dancing']

# %%
person["hobbies"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3b6dce8174b2> in <module>
# ----> 1 person["hobbies"]
#
# KeyError: 'hobbies'

# %%
person["age"]
# Out:
# 52

# %%
person["age"]=32

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 32,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing']}

# %%
person["age"]=person["age"]+1

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 34,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing']}

# %%
person["likes"]=person["likes"]+"Swimming"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-015ee18c8ac8> in <module>
# ----> 1 person["likes"]=person["likes"]+"Swimming"
#
# TypeError: can only concatenate list (not "str") to list

# %%
person["likes"]=person["likes"]+["Swimming"]

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 34,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing', 'Swimming']}

# %%
person["likes"].append("Cooking")

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 34,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing', 'Swimming', 'Cooking']}

# %%
person["state of origin"]="Rivers"

# %%
person
# Out:
# {'name': 'Smith',
#  'age': 34,
#  'marital status': 'married',
#  'likes': ['Singing', 'Dancing', 'Swimming', 'Cooking'],
#  'state of origin': 'Rivers'}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'marital status', 'likes', 'state of origin'])

# %%
person.values()
# Out:
# dict_values(['Smith', 34, 'married', ['Singing', 'Dancing', 'Swimming', 'Cooking'], 'Rivers'])

# %%
person.items()
# Out:
# dict_items([('name', 'Smith'), ('age', 34), ('marital status', 'married'), ('likes', ['Singing', 'Dancing', 'Swimming', 'Cooking']), ('state of origin', 'Rivers')])

# %%
person["age"]
# Out:
# 34

# %%
person.get("age")
# Out:
# 34

# %%
person["country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-692dcfe2a445> in <module>
# ----> 1 person["country"]
#
# KeyError: 'country'

# %%
print(person.get("country"))
# Out:
# None

# %%
if person["country"]:
    print("Nice")
else:
    print("Not found")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-c3e512bd57bf> in <module>
# ----> 1 if person["country"]:
#       2     print("Nice")
#       3 else:
#       4     print("Not found")
#
# KeyError: 'country'

# %%
if person.get("country"):
    print("Nice")
else:
    print("Not found")
# Out:
# Not found

# %% [markdown]
# ## Problem  129

# %%
codes={"A":"2","B":"22","C":"222","O":"666",
       "M":"6","E":"33","H":"44","R":"777"," ":"0"}
sentence=input("Enter a sentence: ").upper()
converted_sentence=""
for letter in sentence:
    converted_sentence=converted_sentence+codes[letter]
print(converted_sentence)
# Out:
# Enter a sentence: come here
# 2226666330443377733

# %%
# Out:
# Enter a sentence: 22
# AA

# %%
abs(-12)
# Out:
# 12

# %%
def chat(name,message):
    """This functions returns messages sent by a user"""
    print(f"{name}:{message}")

# %%
chat("Dan","How are we doing?")
# Out:
# Dan:How are we doing?

# %%
chat("This is me","Jane")
# Out:
# This is me:Jane

# %%
from datetime import datetime

# %%
datetime.day()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0bb45c04e8ed> in <module>
# ----> 1 datetime.day()
#
# TypeError: 'getset_descriptor' object is not callable

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 2, 11, 11, 8, 27, 950110)
